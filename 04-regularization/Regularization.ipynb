# %% [markdown]
# <a href="https://colab.research.google.com/github/HSE-LAMBDA/MLDM-2022/blob/master/04-regularization/Regularization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Boston housing dataset

# %% [markdown]
# In this example we'll try to predict housing prices.

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_boston
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('BostonHousing.csv')
X = data.drop('medv', axis=1)
y = data.medv

# %% [markdown]
# Information about the dataset:

# %%
X.columns = [column.upper() for column in X.columns]

# %%
print(data.DESCR)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9164\367367116.py in ?()
# ----> 1 print(data.DESCR)
#
# C:\PYTHON\Python\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'DESCR'

# %%
X
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# 3       18.7  394.63   2.94
# 4       18.7  396.90   5.33
# ..       ...     ...    ...
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88
#
# [506 rows x 13 columns]

# %% [markdown]
# # Exploring the data

# %% [markdown]
# Let's just see how the target depends on individual features.

# %%
plt.figure(figsize=(15, 15))

grid_size = int(np.ceil(X.shape[1]**0.5))

for i, name in enumerate(X, 1):
    plt.subplot(grid_size, grid_size, i)
    plt.scatter(X[name], y)
    plt.xlabel(name)

# %% [markdown]
# Let's start by trying a simple linear regression model on the features with the most obvious correlation with the target. We'll also scale the features manually.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error

# %%
columns = ["CRIM", "RM", "LSTAT"]

X_subset = X[columns]
X_subset /= X_subset.max()

# %%
X_subset
# Out:
#          CRIM        RM     LSTAT
# 0    0.000071  0.748861  0.131156
# 1    0.000307  0.731321  0.240716
# 2    0.000307  0.818337  0.106136
# 3    0.000364  0.797039  0.077430
# 4    0.000776  0.814009  0.140374
# ..        ...       ...       ...
# 501  0.000704  0.750911  0.254675
# 502  0.000509  0.697039  0.239136
# 503  0.000683  0.794533  0.148538
# 504  0.001232  0.773804  0.170661
# 505  0.000533  0.686788  0.207532
#
# [506 rows x 3 columns]

# %%
model = make_pipeline(
    PolynomialFeatures(9, include_bias=False), # Can you calculate how many features this will result in? :)
    LinearRegression()
)

model.fit(X_subset, y)
print('mse = ', mean_squared_error(y, model.predict(X_subset)))

plt.figure(figsize=(15, 4))
for i, c in enumerate(columns, 1):
  plt.subplot(1, len(columns), i)
  plt.scatter(X[c], y, label='data')
  plt.scatter(X[c], model.predict(X_subset), label='prediction')
  plt.legend()
plt.show()
# Out:
# mse =  4.329234798816953

# %% [markdown]
# # Splitting the data to train and validation parts

# %% [markdown]
# Looks like the fit from above is reasonable, right?
#
# In fact, we cannot know this yet: we fitted and predicted on the same data. Let's split our dataset to get a more reasonable estimate of the prediction error.

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_subset, y, test_size=50, random_state=39)

# %%
model = make_pipeline(
    PolynomialFeatures(9, include_bias=False),
    LinearRegression()
)

model.fit(X_train, y_train)

print('train mse = ', mean_squared_error(y_train, model.predict(X_train)))
print('test mse = ', mean_squared_error(y_test, model.predict(X_test)))
# Out:
# train mse =  3.4453966536988148
# test mse =  119315422908052.2

# %% [markdown]
# That's quite an error we have on the test set!
#
# Let's look at the prediction.

# %%
plt.figure(figsize=(15, 4))
for i, c in enumerate(columns, 1):
  plt.subplot(1, len(columns), i)
  plt.scatter(X_test[c], y_test, label='data')
  plt.scatter(X_test[c], model.predict(X_test), label='prediction')
  plt.legend()

# %% [markdown]
# That's because our parameter values at the solution are enormous:

# %%
model.named_steps['linearregression'].coef_
# Out:
# array([ 1.99809577e+10,  2.34242634e+10,  1.09092416e+10, -1.22708181e+11,
#        -1.82172046e+11, -5.52042447e+10, -1.06939536e+11, -1.02063092e+11,
#        -1.95747703e+10, -1.73903283e+12,  9.40468948e+11,  1.29894233e+12,
#         7.28512036e+11,  4.18878002e+11, -7.58517018e+09,  2.83632010e+11,
#         4.15479760e+11,  1.66561731e+11,  1.43171935e+10, -2.73597591e+12,
#         1.27444811e+13,  5.64765670e+12, -2.91442282e+12, -9.97102211e+12,
#        -2.05840987e+12, -1.67082955e+12, -1.37273508e+12,  2.42192620e+11,
#         1.60608027e+10, -4.81654601e+11, -9.61172670e+11, -6.02765988e+11,
#        -1.15598805e+11,  2.15886240e+09, -5.51166002e+12,  2.06579730e+13,
#         3.30683650e+12, -3.82331339e+13, -3.90263807e+13, -2.42889625e+12,
#         4.58031499e+12,  3.13945491e+13,  1.45542080e+13,  4.22249294e+11,
#         2.40589507e+12,  2.53776243e+12, -1.26845642e+12, -3.86857234e+11,
#         1.02202898e+11,  5.43127688e+11,  1.38196110e+12,  1.20311465e+12,
#         3.79756802e+11,  3.25727462e+09, -1.19694608e+10,  6.82883966e+12,
#         3.06997206e+13, -5.02024228e+12, -6.11339689e+13, -2.15971326e+13,
#         3.80609862e+12,  5.99076857e+13,  1.06568259e+14,  1.64644270e+13,
#        -1.99413621e+12, -3.62992501e+12, -5.18023935e+13, -4.05656921e+13,
#        -3.35336440e+12,  5.48972088e+11, -2.22867917e+12, -2.88093131e+12,
#         2.83128785e+12,  1.68535178e+12, -3.54885452e+11, -1.04661725e+11,
#        -4.06717167e+11, -1.26433820e+12, -1.43082557e+12, -6.53097179e+11,
#        -4.46339565e+10,  4.77302998e+10,  9.04979886e+09,  7.23260037e+11,
#        -2.51575155e+13, -7.86822435e+12, -6.31287595e+13,  1.49001706e+13,
#         9.03861997e+12,  8.90094336e+13,  5.02012386e+13, -1.07774058e+13,
#        -5.18154183e+12, -5.14885132e+13, -1.43719341e+14, -3.96900643e+13,
#         6.24206448e+12,  1.65202264e+12,  1.01541400e+12,  4.71511175e+13,
#         5.56439245e+13,  9.05733289e+12, -1.99930482e+12, -2.46171022e+11,
#         1.29741896e+12,  2.02152442e+12, -3.18326668e+12, -2.97858449e+12,
#         3.26881487e+11,  3.79603615e+11,  3.27593171e+10,  1.95059362e+11,
#         7.18637377e+11,  1.01400872e+12,  6.22216221e+11,  9.52992197e+10,
#        -6.88603919e+10, -2.95929554e+10, -3.20369897e+09,  1.50561995e+11,
#        -2.51033949e+12,  1.56770258e+11,  3.15730708e+13,  1.81226240e+13,
#         3.37911909e+12,  5.70166221e+13, -1.47241771e+13, -1.92254083e+13,
#        -4.48927684e+12, -6.39839923e+13, -4.98745890e+13,  8.83945073e+12,
#         1.17317768e+13,  2.03772258e+12,  2.28691329e+13,  9.57650341e+13,
#         4.06867590e+13, -5.53770923e+12, -4.33032803e+12, -3.58534091e+11,
#         3.25886267e+11, -2.23931129e+13, -3.75483425e+13, -1.01168870e+13,
#         2.18235339e+12,  7.60385498e+11,  1.40939814e+10, -4.33945389e+11,
#        -8.14544300e+11,  1.77917675e+12,  2.37300188e+12,  3.97066161e+10,
#        -4.39764825e+11, -9.08735551e+10, -2.94529366e+09, -5.43752345e+10,
#        -2.31952081e+11, -3.96507608e+11, -3.12059193e+11, -8.07273201e+10,
#         4.16801176e+10,  3.20657345e+10,  7.18308007e+09,  5.69041415e+08,
#        -1.23116048e+11,  6.46331843e+10,  5.10958533e+09,  1.76095942e+12,
#         1.27399326e+11, -2.33597216e+11, -1.35138843e+13, -1.01685990e+13,
#        -4.32576344e+12, -2.53546450e+11, -1.91297499e+13,  4.89490826e+12,
#         1.00383408e+13,  5.13818628e+12,  5.92015664e+11,  1.82155827e+13,
#         1.80506444e+13, -1.77962983e+12, -6.37127955e+12, -2.50499308e+12,
#        -2.26777262e+11, -4.05918256e+12, -2.52416039e+13, -1.50872954e+13,
#         1.15338333e+12,  2.65411111e+12,  5.57843939e+11,  1.25931218e+10,
#        -1.95007459e+11,  4.32117447e+12,  9.97271947e+12,  4.00993024e+12,
#        -6.85854630e+11, -5.32971849e+11, -4.53808529e+10,  3.82642307e+09,
#         6.38191689e+10,  1.45245622e+11, -3.93238327e+11, -7.08939522e+11,
#        -1.15653834e+11,  1.60213931e+11,  6.15206905e+10,  4.73200747e+09,
#         4.64520469e+06,  6.71423446e+09,  3.25385954e+10,  6.59885581e+10,
#         6.44633613e+10,  2.46478518e+10, -8.53592127e+09, -1.14619318e+10,
#        -4.04715960e+09, -6.34236717e+08, -4.32019638e+07])

# %% [markdown]
# # L2 regularization (ridge regression)

# %% [markdown]
# Let's regularize the solution!

# %%
from sklearn.linear_model import Ridge

# %%
model = make_pipeline(
    PolynomialFeatures(9, include_bias=False),
    Ridge(alpha=1.)
)

model.fit(X_train, y_train)

print('train mse = ', mean_squared_error(y_train, model.predict(X_train)))
print('test mse = ', mean_squared_error(y_test, model.predict(X_test)))
# Out:
# train mse =  20.730542787957923
# test mse =  13.099078251952262

# %%
plt.figure(figsize=(15, 4))
for i, c in enumerate(columns, 1):
  plt.subplot(1, len(columns), i)
  plt.scatter(X_test[c], y_test, label='data')
  plt.scatter(X_test[c], model.predict(X_test), label='prediction')
  plt.legend()

# %%
model.named_steps['ridge'].coef_
# Out:
# array([-8.19432282e-01,  6.96058073e-01, -1.02993537e+01, -3.17660586e-01,
#        -1.51026234e+00, -3.57358157e+00,  3.88003254e+00, -1.02027936e+01,
#         2.97680965e-01,  1.96558369e-01, -3.19837630e-01, -4.35602150e-01,
#        -1.65818335e+00, -2.74511153e+00, -2.59731725e+00,  6.54810878e+00,
#        -8.70010830e+00, -1.71878349e+00,  3.08150673e+00,  3.17459374e-01,
#         1.10658344e-01,  9.00027256e-02, -2.87546252e-01, -3.16188950e-01,
#        -3.69123244e-01, -1.60140392e+00, -2.07899220e+00, -1.86907130e+00,
#        -1.75671781e+00,  7.84097799e+00, -6.93436203e+00, -2.36154836e+00,
#         9.43249807e-01,  3.18241320e+00,  3.06844997e-01,  2.01054320e-01,
#         1.76026657e-01,  5.52815158e-02,  6.37473081e-02,  7.04275056e-03,
#        -2.46093197e-01, -2.32640684e-01, -2.38656204e-01, -3.25861641e-01,
#        -1.48523680e+00, -1.56776781e+00, -1.34415981e+00, -1.22049075e+00,
#        -1.24184693e+00,  7.74667369e+00, -5.35964170e+00, -2.36656710e+00,
#        -8.85472649e-02,  1.41627695e+00,  2.63690401e+00,  2.56943591e-01,
#         1.93267728e-01,  1.72885861e-01,  1.22474678e-01,  1.19983904e-01,
#         7.76151813e-02,  2.10042345e-02,  4.09805477e-02,  1.80513723e-02,
#        -5.07286957e-02, -2.05981434e-01, -1.73105272e-01, -1.59245653e-01,
#        -1.96574705e-01, -3.01777363e-01, -1.36849659e+00, -1.18518840e+00,
#        -9.67958260e-01, -8.52833695e-01, -8.39329939e-01, -9.35567435e-01,
#         6.54042794e+00, -4.11824932e+00, -2.10888579e+00, -5.30670945e-01,
#         4.90716658e-01,  1.27414199e+00,  2.01936172e+00,  1.98464209e-01,
#         1.57836509e-01,  1.47801676e-01,  1.17465255e-01,  1.14419693e-01,
#         8.62956554e-02,  7.07771001e-02,  7.87810058e-02,  5.95486237e-02,
#         1.55745831e-02,  8.40039364e-04,  2.38352831e-02,  1.74252774e-02,
#        -1.68130104e-02, -8.65960330e-02, -1.71070845e-01, -1.30014047e-01,
#        -1.09221250e-01, -1.22375772e-01, -1.75239244e-01, -2.85341632e-01,
#        -1.27172880e+00, -9.03048591e-01, -6.99051433e-01, -5.98955129e-01,
#        -5.73031321e-01, -6.17515589e-01, -7.46398694e-01,  4.55148453e+00,
#        -3.21751267e+00, -1.77424774e+00, -6.69133997e-01,  3.11612789e-02,
#         5.42522437e-01,  9.94695884e-01,  1.48082819e+00,  1.42158066e-01,
#         1.16819649e-01,  1.18016351e-01,  9.28246327e-02,  9.49765222e-02,
#         7.84073975e-02,  6.79121104e-02,  7.34964447e-02,  6.08518639e-02,
#         3.38157647e-02,  3.76377891e-02,  4.98168745e-02,  4.26500687e-02,
#         2.00828636e-02, -2.12020030e-02, -1.01785242e-02,  1.19747601e-02,
#         1.32355061e-02, -3.11158719e-03, -3.94814265e-02, -1.06799666e-01,
#        -1.42277523e-01, -9.84504890e-02, -7.66410962e-02, -7.85518880e-02,
#        -1.04521161e-01, -1.62267422e-01, -2.71424243e-01, -1.19914791e+00,
#        -6.96840280e-01, -5.07023724e-01, -4.22597977e-01, -3.94445701e-01,
#        -4.12968672e-01, -4.82557355e-01, -6.22614080e-01,  2.07438504e+00,
#        -2.61246368e+00, -1.44926138e+00, -6.60497282e-01, -1.75253678e-01,
#         1.64258004e-01,  4.43676388e-01,  7.21157024e-01,  1.04929418e+00,
#         9.16211688e-02,  7.76378930e-02,  8.90811260e-02,  6.43581811e-02,
#         7.32328017e-02,  6.56344953e-02,  5.10270194e-02,  5.91433544e-02,
#         5.27633523e-02,  3.66486915e-02,  3.62365067e-02,  4.56247355e-02,
#         4.12963005e-02,  2.74235013e-02,  3.31200728e-03,  1.70136141e-02,
#         3.01352450e-02,  2.90774447e-02,  1.79399984e-02, -3.85520397e-03,
#        -4.19791177e-02, -1.54660335e-02,  4.30047535e-03,  8.75289942e-03,
#         1.58723769e-03, -1.72319016e-02, -5.26811015e-02, -1.16930665e-01,
#        -1.19274261e-01, -7.51355921e-02, -5.47762617e-02, -5.18614074e-02,
#        -6.40936928e-02, -9.43937017e-02, -1.52351761e-01, -2.58497540e-01,
#        -1.14856929e+00, -5.46994785e-01, -3.69896873e-01, -2.99481237e-01,
#        -2.73362064e-01, -2.79147796e-01, -3.16777044e-01, -3.95182739e-01,
#        -5.36850494e-01, -6.57159850e-01, -2.24371554e+00, -1.16933272e+00,
#        -5.88723980e-01, -2.48507798e-01, -1.93100503e-02,  1.56982140e-01,
#         3.17227311e-01,  4.92614507e-01,  7.16084539e-01])

# %% [markdown]
# Now we'll study how losses and parameter values depend on the regularization power.

# %%
from tqdm import tqdm

# %%
reg_powers = np.logspace(-12, 5, 18 * 5, base=10)


train_mse = []
test_mse = []

params = []

for alpha in tqdm(reg_powers):
  linear_model = Ridge(alpha=alpha)
  model = make_pipeline(
    PolynomialFeatures(9, include_bias=False),
    linear_model
  )
  model.fit(X_train, y_train)

  params.append(
      np.append(linear_model.coef_,
                linear_model.intercept_)
  )

  train_mse.append(mean_squared_error(y_train, model.predict(X_train)))
  test_mse.append(mean_squared_error(y_test, model.predict(X_test)))

params = np.array(params)


plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)

plt.plot(1. / reg_powers, train_mse, label='train')
plt.plot(1. / reg_powers, test_mse, label='test')
plt.ylabel('MSE')
plt.xlabel('inverse regularization power')
plt.legend()
plt.xscale('log')
plt.yscale('log')

plt.subplot(1, 2, 2)
plt.plot(1. / reg_powers, np.abs(params));
plt.xlabel("inverse regularization power")
plt.ylabel("parameter magnitude")
plt.xscale('log')
plt.yscale('log')
# Out:
# 100%|██████████| 90/90 [00:00<00:00, 132.76it/s]

# %% [markdown]
# # L1 regularization (lasso regression)

# %% [markdown]
# Here's a similar study with the Lasso regression:

# %%
from sklearn.linear_model import Lasso

# %%
reg_powers = np.logspace(-4, 1, 6 * 5, base=10)

train_mse = []
test_mse = []

params = []

for alpha in tqdm(reg_powers):
  # Lasso doesn't have an analytic solution. Instead it
  # utilizes an iterative procedure, which for small
  # alpha values may take a while to converge.
  linear_model = Lasso(alpha=alpha, max_iter=1000000)
  model = make_pipeline(
    PolynomialFeatures(9, include_bias=False),
    linear_model
  )
  model.fit(X_train, y_train)

  params.append(
      np.append(linear_model.coef_,
                linear_model.intercept_)
  )

  train_mse.append(mean_squared_error(y_train, model.predict(X_train)))
  test_mse.append(mean_squared_error(y_test, model.predict(X_test)))

params = np.array(params)

plt.figure(figsize=(18, 5))

plt.subplot(1, 3, 1)

plt.plot(1. / reg_powers, train_mse, label='train')
plt.plot(1. / reg_powers, test_mse, label='test')
plt.ylabel('MSE')
plt.xlabel('inverse regularization power')
plt.legend()
plt.xscale('log')

plt.subplot(1, 3, 2)
plt.plot(1. / reg_powers, np.abs(params));
plt.xlabel("inverse regularization power")
plt.ylabel("parameter magnitude")
plt.xscale('log')
plt.yscale('log')

plt.subplot(1, 3, 3)
plt.plot(1. / reg_powers, np.isclose(params, 0.).sum(axis=1));
plt.xlabel("inverse regularization power")
plt.ylabel("# zero parameters")
plt.xscale('log')
# Out:
# 100%|██████████| 30/30 [00:39<00:00,  1.32s/it]

# %% [markdown]
# # Bonus. What features are the most powerful?

# %% [markdown]
# Let's see what features are most powerful for a reasonably performing model (e.g. 1/alpha = 100) **(2 points)**:

# %%
model = make_pipeline(
  PolynomialFeatures(9, include_bias=False),
  Lasso(alpha=0.01, max_iter=1000000)
)
model.fit(X_train, y_train)

print('train mse = ', mean_squared_error(y_train, model.predict(X_train)))
print('test mse = ', mean_squared_error(y_test, model.predict(X_test)))
# Out:
# train mse =  20.203747681232112
# test mse =  13.279378196425576

# %% [markdown]
# Some hints:
#  - You can explore the feature names using `get_feature_names` method of the `PolynomialFeatures` class (plug the list of original feature names to get reasonable output).
#  - `model.named_steps['polynomialfeatures']` to get the `PolynomialFeatures` preprocessor of our model.
#  - `model.named_steps['lasso'].coef_` to get the parameters of the linear model
#  - `np.argwhere` to find indices of non-zero elements of an array

# %%
np.stack([model.named_steps['polynomialfeatures'].get_feature_names_out(), model.named_steps['lasso'].coef_])[:,np.argwhere(model.named_steps['lasso'].coef_)].T
# Out:
# array([[['CRIM LSTAT', -18.464804407896153],
#         ['RM LSTAT', -19.202476566027617],
#         ['RM^2 LSTAT', -39.35581846945327],
#         ['LSTAT^3', 12.935625712055424],
#         ['RM^4', 35.650439792508465],
#         ['RM^5', 1.7786317787761206]]], dtype=object)
